# %%
import meep as mp
import matplotlib.pyplot as plt
import numpy as np 
from IPython.display import Video 
from meep import mpb
from scipy.optimize import minimize
import math
import os
import utils as u

# %%
taper = u.tapering(382,90,11)
u.banddiagram_wmpb(width= 500, length = 337, xlength=218, ylength= 90, show_geometry= True)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (1,1.48368,0.652819)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      ellipsoid, center = (0,0,0)
#           size (0.646884,0.267062,0.652819)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1,1.48368,0.652819)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.646884,0.267062,0.652819)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 4 and 19 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 32 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.016129032258064516, 0.0, 0.0>
#   Vector3<0.03225806451612903, 0.0, 0.0>
#   Vector3<0.04838709677419355, 0.0, 0.0>
#   Vector3<0.06451612903225806, 0.0, 0.0>
#   Vector3<0.08064516129032258, 0.0, 0.0>
#   Vector3<0.0967741935483871, 0.0, 0.0>
#   Vector3<0.11290322580645161, 0.0, 0.0>
#   Vector3<0.12903225806451613, 0.0, 0.0>
#   Vector3<0.14516129032258063, 0.0, 0.0>
#   Vector3<0.16129032258064516, 0.0, 0.0>
#   Vector3<0.1774193548387097, 0.0, 0.0>
#   Vector3<0.1935483870967742, 0.0, 0.0>
#   Vector3<0.2096774193548387, 0.0, 0.0>
#   Vector3<0.22580645161290322, 0.0, 0.0>
#   Vector3<0.24193548387096775, 0.0, 0.0>
#   Vector3<0.25806451612903225, 0.0, 0.0>
#   Vector3<0.27419354838709675, 0.0, 0.0>
#   Vector3<0.29032258064516125, 0.0, 0.0>
#   Vector3<0.3064516129032258, 0.0, 0.0>
#   Vector3<0.3225806451612903, 0.0, 0.0>
#   Vector3<0.3387096774193548, 0.0, 0.0>
#   Vector3<0.3548387096774194, 0.0, 0.0>
#   Vector3<0.3709677419354839, 0.0, 0.0>
#   Vector3<0.3870967741935484, 0.0, 0.0>
#   Vector3<0.4032258064516129, 0.0, 0.0>
#   Vector3<0.4193548387096774, 0.0, 0.0>
#   Vector3<0.43548387096774194, 0.0, 0.0>
#   Vector3<0.45161290322580644, 0.0, 0.0>
#   Vector3<0.46774193548387094, 0.0, 0.0>
#   Vector3<0.4838709677419355, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.03387331962585449
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 2 to 2...
#     near maximum in trace
#     iteration    1: trace = 0.3733406887760833 (198.104% change)
#     iteration    2: trace = 0.1111459445427237 (108.236% change)
#     iteration    3: trace = 0.09901907457841004 (11.5403% change)
#     iteration    4: trace = 0.0936799619507086 (5.5414% change)
#     iteration    5: trace = 0.09146208252446321 (2.39587% change)
#     iteration    6: trace = 0.08946002131181983 (2.21317% change)
#     iteration    7: trace = 0.08738362409445753 (2.34829% change)
#     iteration    8: trace = 0.08686451869416216 (0.595823% change)
#     iteration    9: trace = 0.08662128655071924 (0.280406% change)
#     iteration   10: trace = 0.08657265609743492 (0.0561572% change)
#     iteration   11: trace = 0.08655347318570394 (0.0221606% change)
#     iteration   12: trace = 0.08653650174328985 (0.01961% change)
#     iteration   13: trace = 0.08652865170867634 (0.00907177% change)
#     iteration   14: trace = 0.08652583288982076 (0.00325772% change)
#     iteration   15: trace = 0.08652521551671015 (0.000713516% change)
#     iteration   16: trace = 0.08652512723688814 (0.000102028% change)
#     iteration   17: trace = 0.08652511039094757 (1.94694e-05% change)
#     iteration   18: trace = 0.0865251046274875 (6.66103e-06% change)
# Finished solving for bands 2 to 2 after 18 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.294151
# elapsed time for k point: 0.1350572109222412
# solve_kpoint (0.016129,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.08657644164740989 (0.0871811% change)
#     iteration    2: trace = 0.08656645284813808 (0.0115382% change)
#     iteration    3: trace = 0.08655233832544483 (0.0163062% change)
#     iteration    4: trace = 0.08655011562471701 (0.00256808% change)
#     iteration    5: trace = 0.086549053255032 (0.00122747% change)
#     iteration    6: trace = 0.08654891735310438 (0.000157023% change)
#     iteration    7: trace = 0.0865488347516232 (9.54391e-05% change)
#     iteration    8: trace = 0.08654876059725539 (8.56793e-05% change)
#     iteration    9: trace = 0.08654871515084345 (5.25096e-05% change)
#     iteration   10: trace = 0.08654870315843656 (1.38563e-05% change)
#     iteration   11: trace = 0.08654870090523092 (2.6034e-06% change)
# Finished solving for bands 1 to 2 after 11 iterations.
# tefreqs:, 2, 0.016129, 0, 0, 0.016129, 0.00559546, 0.294138
# elapsed time for k point: 0.1919243335723877
# solve_kpoint (0.0322581,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.08664489115006827 (0.0880382% change)
#     iteration    2: trace = 0.08663314959126932 (0.0135523% change)
#     iteration    3: trace = 0.08661465458414688 (0.0213509% change)
#     iteration    4: trace = 0.08661097232665578 (0.0042514% change)
#     iteration    5: trace = 0.08660907788924302 (0.00218732% change)
#     iteration    6: trace = 0.08660856857786561 (0.000588059% change)
#     iteration    7: trace = 0.08660799139402368 (0.00066643% change)
#     iteration    8: trace = 0.08660773989142752 (0.000290392% change)
#     iteration    9: trace = 0.08660765350131987 (9.97488e-05% change)
#     iteration   10: trace = 0.08660763855272111 (1.72601e-05% change)
#     iteration   11: trace = 0.0866076354718224 (3.55731e-06% change)
# Finished solving for bands 1 to 2 after 11 iterations.
# tefreqs:, 3, 0.0322581, 0, 0, 0.0322581, 0.0111894, 0.294079
# elapsed time for k point: 0.3542618751525879
# solve_kpoint (0.0483871,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.08672129353401745 (0.0914739% change)
#     iteration    2: trace = 0.08670399779292159 (0.019946% change)
#     iteration    3: trace = 0.08667435549138261 (0.0341938% change)
#     iteration    4: trace = 0.08666697670340279 (0.00851359% change)
#     iteration    5: trace = 0.08666294185569354 (0.00465569% change)
#     iteration    6: trace = 0.08666153197203944 (0.00162687% change)
#     iteration    7: trace = 0.08666012811548239 (0.00161994% change)
#     iteration    8: trace = 0.08665973030858554 (0.000459044% change)
#     iteration    9: trace = 0.08665960708510154 (0.000142192% change)
#     iteration   10: trace = 0.0866595854918291 (2.49173e-05% change)
#     iteration   11: trace = 0.08665958064629067 (5.59146e-06% change)
# Finished solving for bands 1 to 2 after 11 iterations.
# tefreqs:, 4, 0.0483871, 0, 0, 0.0483871, 0.0167801, 0.293901
# elapsed time for k point: 0.1561276912689209
# solve_kpoint (0.0645161,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.08672420008914594 (0.098168% change)
#     switching to approximate line minimization (decrease time by 80.591%)
#     iteration    2: trace = 0.08669353436222677 (0.0353663% change)
#     switching back to exact line minimization
#     iteration    3: trace = 0.08663933041879748 (0.0625432% change)
#     iteration    4: trace = 0.08662368504515049 (0.0180597% change)
#     iteration    5: trace = 0.08661538007760797 (0.00958787% change)
#     iteration    6: trace = 0.08661248819598552 (0.00333882% change)
#     iteration    7: trace = 0.086610115748244 (0.00273919% change)
#     iteration    8: trace = 0.08660955094941905 (0.000652119% change)
#     iteration    9: trace = 0.08660937079548436 (0.000208007% change)
#     iteration   10: trace = 0.08660933727600549 (3.87019e-05% change)
#     iteration   11: trace = 0.08660932925430387 (9.26194e-06% change)
# Finished solving for bands 1 to 2 after 11 iterations.
# tefreqs:, 5, 0.0645161, 0, 0, 0.0645161, 0.0223662, 0.293443
# elapsed time for k point: 0.14645648002624512
# solve_kpoint (0.0806452,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.08648774195168084 (0.108186% change)
#     iteration    2: trace = 0.08642919897043817 (0.0677123% change)
#     iteration    3: trace = 0.0863325194500518 (0.111922% change)
#     iteration    4: trace = 0.08630283763508206 (0.0343867% change)
#     iteration    5: trace = 0.08628866768515013 (0.0164202% change)
#     iteration    6: trace = 0.08628418911647791 (0.00519035% change)
#     switching to approximate line minimization (decrease time by 82.1814%)
#     iteration    7: trace = 0.08628110398800005 (0.00357561% change)
#     iteration    8: trace = 0.08628042639936692 (0.00078533% change)
#     switching back to exact line minimization
#     iteration    9: trace = 0.08628019102274403 (0.000272805% change)
#     iteration   10: trace = 0.08628014348419034 (5.50979e-05% change)
#     iteration   11: trace = 0.08628012997202054 (1.56608e-05% change)
#     iteration   12: trace = 0.08628012462878101 (6.1929e-06% change)
# Finished solving for bands 1 to 2 after 12 iterations.
# tefreqs:, 6, 0.0806452, 0, 0, 0.0806452, 0.027946, 0.292402
# elapsed time for k point: 0.10270047187805176
# solve_kpoint (0.0967742,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.0857549601966168 (0.116312% change)
#     iteration    2: trace = 0.08566127090521955 (0.109312% change)
#     iteration    3: trace = 0.08553243002958287 (0.150521% change)
#     iteration    4: trace = 0.08549315016946496 (0.0459345% change)
#     iteration    5: trace = 0.08547721838465712 (0.0186369% change)
#     switching to approximate line minimization (decrease time by 79.5675%)
#     iteration    6: trace = 0.08547278254167909 (0.00518964% change)
#     switching back to exact line minimization
#     iteration    7: trace = 0.08547013421727111 (0.00309849% change)
#     iteration    8: trace = 0.08546958881933922 (0.000638117% change)
#     switching to approximate line minimization (decrease time by 54.5146%)
#     iteration    9: trace = 0.08546938224219652 (0.000241697% change)
#     switching back to exact line minimization
#     iteration   10: trace = 0.08546933798727203 (5.17787e-05% change)
#     iteration   11: trace = 0.08546932350148256 (1.69485e-05% change)
#     iteration   12: trace = 0.08546931495213406 (1.00028e-05% change)
#     iteration   13: trace = 0.08546930263351041 (1.44129e-05% change)
#     iteration   14: trace = 0.08546929112339784 (1.3467e-05% change)
#     iteration   15: trace = 0.08546928511507083 (7.02981e-06% change)
# Finished solving for bands 1 to 2 after 15 iterations.
# tefreqs:, 7, 0.0967742, 0, 0, 0.0967742, 0.0335179, 0.290424
# elapsed time for k point: 0.20755672454833984
# solve_kpoint (0.112903,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.08440868422032066 (0.112784% change)
#     iteration    2: trace = 0.08431229579074657 (0.114258% change)
#     iteration    3: trace = 0.08420579557727852 (0.126396% change)
#     iteration    4: trace = 0.08417346237459186 (0.0384052% change)
#     iteration    5: trace = 0.08416304516552489 (0.0123766% change)
#     iteration    6: trace = 0.08416035945435969 (0.00319113% change)
#     iteration    7: trace = 0.08415903976784865 (0.00156807% change)
#     iteration    8: trace = 0.08415876949068181 (0.000321151% change)
#     iteration    9: trace = 0.0841586615361017 (0.000128275% change)
#     iteration   10: trace = 0.08415863934278277 (2.63708e-05% change)
#     iteration   11: trace = 0.08415863242470482 (8.22028e-06% change)
# Finished solving for bands 1 to 2 after 11 iterations.
# tefreqs:, 8, 0.112903, 0, 0, 0.112903, 0.0390803, 0.287457
# elapsed time for k point: 0.2256455421447754
# solve_kpoint (0.129032,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.08267939534359423 (0.0969927% change)
#     iteration    2: trace = 0.08261872834299643 (0.0734031% change)
#     iteration    3: trace = 0.08255974476934497 (0.071418% change)
#     iteration    4: trace = 0.08254094665077372 (0.0227717% change)
#     iteration    5: trace = 0.08253570611719122 (0.00634921% change)
#     iteration    6: trace = 0.08253445907624522 (0.00151092% change)
#     iteration    7: trace = 0.0825339412611889 (0.000627395% change)
#     iteration    8: trace = 0.08253384491287086 (0.000116738% change)
#     iteration    9: trace = 0.08253380259782103 (5.12699e-05% change)
#     iteration   10: trace = 0.08253379464720864 (9.63316e-06% change)
# Finished solving for bands 1 to 2 after 10 iterations.
# tefreqs:, 9, 0.129032, 0, 0, 0.129032, 0.0446313, 0.283799
# elapsed time for k point: 0.16794633865356445
# solve_kpoint (0.145161,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.08085292433230738 (0.0828751% change)
#     iteration    2: trace = 0.0808191680150501 (0.041759% change)
#     iteration    3: trace = 0.08078913089392394 (0.0371727% change)
#     iteration    4: trace = 0.08077918569964763 (0.0123108% change)
#     iteration    5: trace = 0.08077650475911398 (0.00331891% change)
#     iteration    6: trace = 0.08077594004372921 (0.000699111% change)
#     iteration    7: trace = 0.08077574340237126 (0.000243441% change)
#     iteration    8: trace = 0.08077570699438417 (4.50729e-05% change)
#     iteration    9: trace = 0.08077569213250917 (1.83989e-05% change)
#     iteration   10: trace = 0.08077568901557869 (3.85875e-06% change)
# Finished solving for bands 1 to 2 after 10 iterations.
# tefreqs:, 10, 0.145161, 0, 0, 0.145161, 0.0501692, 0.279748
# elapsed time for k point: 0.18476557731628418
# solve_kpoint (0.16129,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.0790303155048853 (0.073691% change)
#     iteration    2: trace = 0.07901131418263686 (0.024046% change)
#     iteration    3: trace = 0.07899571206811545 (0.0197486% change)
#     iteration    4: trace = 0.0789904080132887 (0.00671458% change)
#     iteration    5: trace = 0.07898895220616231 (0.00184303% change)
#     iteration    6: trace = 0.07898867853199035 (0.000346472% change)
#     iteration    7: trace = 0.07898859342210607 (0.00010775% change)
#     iteration    8: trace = 0.07898857988940575 (1.71325e-05% change)
#     iteration    9: trace = 0.07898857504996148 (6.12676e-06% change)
# Finished solving for bands 1 to 2 after 9 iterations.
# tefreqs:, 11, 0.16129, 0, 0, 0.16129, 0.0556921, 0.275476
# elapsed time for k point: 0.10245490074157715
# solve_kpoint (0.177419,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.07724974821040435 (0.0682008% change)
#     iteration    2: trace = 0.07723828656705832 (0.0148382% change)
#     iteration    3: trace = 0.077229720145274 (0.0110915% change)
#     iteration    4: trace = 0.07722680523323933 (0.00377441% change)
#     iteration    5: trace = 0.07722595180834665 (0.0011051% change)
#     iteration    6: trace = 0.07722580584740116 (0.000189005% change)
#     iteration    7: trace = 0.07722576434927866 (5.37361e-05% change)
#     iteration    8: trace = 0.07722575873183619 (7.27405e-06% change)
# Finished solving for bands 1 to 2 after 8 iterations.
# tefreqs:, 12, 0.177419, 0, 0, 0.177419, 0.061198, 0.271073
# elapsed time for k point: 0.0889892578125
# solve_kpoint (0.193548,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.07552980679573783 (0.0649913% change)
#     iteration    2: trace = 0.07552231914651418 (0.00991399% change)
#     iteration    3: trace = 0.07551731924710776 (0.00662065% change)
#     iteration    4: trace = 0.07551567046033297 (0.00218335% change)
#     iteration    5: trace = 0.07551514253128658 (0.000699101% change)
#     iteration    6: trace = 0.07551505971895063 (0.000109663% change)
#     iteration    7: trace = 0.07551503624786085 (3.10813e-05% change)
#     iteration    8: trace = 0.07551503339664606 (3.77569e-06% change)
# Finished solving for bands 1 to 2 after 8 iterations.
# tefreqs:, 13, 0.193548, 0, 0, 0.193548, 0.0666848, 0.266586
# elapsed time for k point: 0.07556915283203125
# solve_kpoint (0.209677,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.07388140760433545 (0.063171% change)
#     iteration    2: trace = 0.07387614254724094 (0.00712662% change)
#     iteration    3: trace = 0.07387305058601684 (0.00418542% change)
#     iteration    4: trace = 0.07387209840298292 (0.00128895% change)
#     iteration    5: trace = 0.07387176565942367 (0.000450433% change)
#     iteration    6: trace = 0.07387171429080133 (6.95376e-05% change)
#     iteration    7: trace = 0.07387169988045729 (1.95073e-05% change)
#     iteration    8: trace = 0.07387169818249069 (2.29853e-06% change)
# Finished solving for bands 1 to 2 after 8 iterations.
# tefreqs:, 14, 0.209677, 0, 0, 0.209677, 0.07215, 0.262042
# elapsed time for k point: 0.1364305019378662
# solve_kpoint (0.225806,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.0723114196773883 (0.0622363% change)
#     iteration    2: trace = 0.07230746991899245 (0.0054623% change)
#     iteration    3: trace = 0.07230545155889309 (0.0027914% change)
#     iteration    4: trace = 0.07230489649306249 (0.000767671% change)
#     iteration    5: trace = 0.07230468187721563 (0.000296821% change)
#     iteration    6: trace = 0.07230464897141425 (4.55099e-05% change)
#     iteration    7: trace = 0.0723046395952863 (1.29675e-05% change)
#     iteration    8: trace = 0.07230463847096262 (1.55498e-06% change)
# Finished solving for bands 1 to 2 after 8 iterations.
# tefreqs:, 15, 0.225806, 0, 0, 0.225806, 0.0775912, 0.257457
# elapsed time for k point: 0.1439499855041504
# solve_kpoint (0.241935,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.07082426453518262 (0.0618741% change)
#     iteration    2: trace = 0.07082113290218039 (0.00442179% change)
#     iteration    3: trace = 0.07081974633514759 (0.00195786% change)
#     iteration    4: trace = 0.07081942152404624 (0.000458646% change)
#     iteration    5: trace = 0.07081928238375997 (0.000196472% change)
#     iteration    6: trace = 0.07081926100962543 (3.01812e-05% change)
#     iteration    7: trace = 0.07081925472065241 (8.88031e-06% change)
# Finished solving for bands 1 to 2 after 7 iterations.
# tefreqs:, 16, 0.241935, 0, 0, 0.241935, 0.0830052, 0.252843
# elapsed time for k point: 0.11431574821472168
# solve_kpoint (0.258065,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06942284128983391 (0.0618886% change)
#     iteration    2: trace = 0.06942023902191986 (0.0037485% change)
#     iteration    3: trace = 0.06941923947431833 (0.00143986% change)
#     iteration    4: trace = 0.06941904663711243 (0.000277787% change)
#     iteration    5: trace = 0.06941895786870536 (0.000127873% change)
#     iteration    6: trace = 0.06941894424709301 (1.96223e-05% change)
#     iteration    7: trace = 0.06941894003834949 (6.06282e-06% change)
# Finished solving for bands 1 to 2 after 7 iterations.
# tefreqs:, 17, 0.258065, 0, 0, 0.258065, 0.0883887, 0.248206
# elapsed time for k point: 0.06563663482666016
# solve_kpoint (0.274194,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06810906512802216 (0.0621705% change)
#     iteration    2: trace = 0.06810681581143059 (0.00330258% change)
#     iteration    3: trace = 0.06810606176845722 (0.00110715% change)
#     iteration    4: trace = 0.06810594784873045 (0.000167268% change)
#     iteration    5: trace = 0.0681058915164785 (8.27127e-05% change)
#     iteration    6: trace = 0.06810588284101277 (1.27382e-05% change)
#     iteration    7: trace = 0.06810588003794904 (4.11574e-06% change)
# Finished solving for bands 1 to 2 after 7 iterations.
# tefreqs:, 18, 0.274194, 0, 0, 0.274194, 0.0937376, 0.243555
# elapsed time for k point: 0.050496816635131836
# solve_kpoint (0.290323,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06688421117035172 (0.0626301% change)
#     iteration    2: trace = 0.06688220179073741 (0.00300431% change)
#     iteration    3: trace = 0.06688160868996541 (0.000886788% change)
#     iteration    4: trace = 0.06688153990498714 (0.000102846% change)
#     iteration    5: trace = 0.066881504910472 (5.23231e-05% change)
#     iteration    6: trace = 0.06688149957732067 (7.97403e-06% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tefreqs:, 19, 0.290323, 0, 0, 0.290323, 0.0990471, 0.238896
# elapsed time for k point: 0.053112030029296875
# solve_kpoint (0.306452,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06574912006611898 (0.0632261% change)
#     iteration    2: trace = 0.06574727629104581 (0.0028043% change)
#     switching to approximate line minimization (decrease time by 95.1336%)
#     iteration    3: trace = 0.06574679302194454 (0.000735043% change)
#     iteration    4: trace = 0.06574674812272269 (6.82911e-05% change)
#     iteration    5: trace = 0.06574672583245658 (3.39032e-05% change)
#     iteration    6: trace = 0.06574672259871914 (4.91848e-06% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tefreqs:, 20, 0.306452, 0, 0, 0.306452, 0.104311, 0.234235
# elapsed time for k point: 0.06822943687438965
# solve_kpoint (0.322581,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06470433225593454 (0.0638641% change)
#     iteration    2: trace = 0.06470260270757718 (0.00267304% change)
#     iteration    3: trace = 0.06470219571847538 (0.000629017% change)
#     iteration    4: trace = 0.06470216558777338 (4.65683e-05% change)
#     iteration    5: trace = 0.06470215188077882 (2.11848e-05% change)
#     iteration    6: trace = 0.0647021500484803 (2.8319e-06% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tefreqs:, 21, 0.322581, 0, 0, 0.322581, 0.109522, 0.22958
# elapsed time for k point: 0.07466650009155273
# solve_kpoint (0.33871,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06375019377036266 (0.0645419% change)
#     iteration    2: trace = 0.06374854047533818 (0.00259343% change)
#     iteration    3: trace = 0.06374818836730892 (0.00055234% change)
#     iteration    4: trace = 0.06374816626268712 (3.46749e-05% change)
#     iteration    5: trace = 0.0637481573948185 (1.39108e-05% change)
#     iteration    6: trace = 0.06374815635050424 (1.63819e-06% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tefreqs:, 22, 0.33871, 0, 0, 0.33871, 0.114669, 0.224942
# elapsed time for k point: 0.04789400100708008
# solve_kpoint (0.354839,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06288690217862854 (0.0652274% change)
#     iteration    2: trace = 0.06288529873462796 (0.00254976% change)
#     iteration    3: trace = 0.06288498769623457 (0.000494613% change)
#     iteration    4: trace = 0.06288496977993115 (2.84906e-05% change)
#     iteration    5: trace = 0.06288496337564545 (1.01841e-05% change)
#     iteration    6: trace = 0.06288496269633409 (1.08024e-06% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tefreqs:, 23, 0.354839, 0, 0, 0.354839, 0.11974, 0.220334
# elapsed time for k point: 0.05374002456665039
# solve_kpoint (0.370968,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06211455939679267 (0.0658974% change)
#     iteration    2: trace = 0.06211298658494392 (0.00253215% change)
#     iteration    3: trace = 0.06211270739703154 (0.000449485% change)
#     iteration    4: trace = 0.06211269145470323 (2.56668e-05% change)
#     iteration    5: trace = 0.06211268609855565 (8.62327e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tefreqs:, 24, 0.370968, 0, 0, 0.370968, 0.124715, 0.215775
# elapsed time for k point: 0.048960208892822266
# solve_kpoint (0.387097,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06143320192427799 (0.0665331% change)
#     iteration    2: trace = 0.06143164641541392 (0.00253206% change)
#     iteration    3: trace = 0.06143139178752414 (0.000414491% change)
#     iteration    4: trace = 0.06143137639422727 (2.50577e-05% change)
#     iteration    5: trace = 0.06143137134341217 (8.22188e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tefreqs:, 25, 0.387097, 0, 0, 0.387097, 0.129568, 0.21129
# elapsed time for k point: 0.054616689682006836
# solve_kpoint (0.403226,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06084282162139787 (0.0671154% change)
#     iteration    2: trace = 0.0608412732177669 (0.00254496% change)
#     iteration    3: trace = 0.06084103962855483 (0.000383933% change)
#     iteration    4: trace = 0.0608410242228194 (2.53213e-05% change)
#     iteration    5: trace = 0.06084101909853458 (8.42242e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tefreqs:, 26, 0.403226, 0, 0, 0.403226, 0.134258, 0.20692
# elapsed time for k point: 0.04933309555053711
# solve_kpoint (0.419355,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06034338670949174 (0.067634% change)
#     iteration    2: trace = 0.06034183900134052 (0.00256487% change)
#     iteration    3: trace = 0.06034162280511207 (0.000358286% change)
#     iteration    4: trace = 0.06034160704842201 (2.61125e-05% change)
#     iteration    5: trace = 0.06034160176971873 (8.74803e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tefreqs:, 27, 0.419355, 0, 0, 0.419355, 0.138726, 0.202723
# elapsed time for k point: 0.041573286056518555
# solve_kpoint (0.435484,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.05993485199857299 (0.0680748% change)
#     iteration    2: trace = 0.0599333010918324 (0.00258769% change)
#     iteration    3: trace = 0.05993309920019881 (0.000336861% change)
#     iteration    4: trace = 0.05993308297898901 (2.70655e-05% change)
#     iteration    5: trace = 0.0599330775856133 (8.999e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tefreqs:, 28, 0.435484, 0, 0, 0.435484, 0.142879, 0.198793
# elapsed time for k point: 0.07897758483886719
# solve_kpoint (0.451613,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.05961716935182584 (0.0684274% change)
#     iteration    2: trace = 0.05961561326290295 (0.00261017% change)
#     iteration    3: trace = 0.05961542273984689 (0.000319586% change)
#     iteration    4: trace = 0.05961540606031927 (2.79785e-05% change)
#     iteration    5: trace = 0.05961540061860592 (9.12803e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tefreqs:, 29, 0.451613, 0, 0, 0.451613, 0.146569, 0.195277
# elapsed time for k point: 0.08425426483154297
# solve_kpoint (0.467742,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.05939029455636039 (0.0686838% change)
#     iteration    2: trace = 0.05938873282952793 (0.00262963% change)
#     iteration    3: trace = 0.05938855070754214 (0.000306661% change)
#     iteration    4: trace = 0.05938853364256082 (2.87345e-05% change)
#     iteration    5: trace = 0.05938852819954342 (9.1651e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tefreqs:, 30, 0.467742, 0, 0, 0.467742, 0.149573, 0.192396
# elapsed time for k point: 0.08840489387512207
# solve_kpoint (0.483871,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.05925419249470931 (0.0688379% change)
#     iteration    2: trace = 0.05925262582889171 (0.00264401% change)
#     iteration    3: trace = 0.05925244903214526 (0.000298378% change)
#     iteration    4: trace = 0.05925243169362461 (2.92621e-05% change)
#     iteration    5: trace = 0.05925242626139196 (9.16795e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tefreqs:, 31, 0.483871, 0, 0, 0.483871, 0.151589, 0.190455
# elapsed time for k point: 0.09386324882507324
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.05920884065806351 (0.0688858% change)
#     iteration    2: trace = 0.05920727052154148 (0.0026519% change)
#     iteration    3: trace = 0.05920709586683776 (0.000294989% change)
#     iteration    4: trace = 0.05920707838833192 (2.9521e-05% change)
#     iteration    5: trace = 0.05920707294776396 (9.18905e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tefreqs:, 32, 0.5, 0, 0, 0.5, 0.152307, 0.189762
# elapsed time for k point: 0.11841654777526855
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.15230688173969872 at Vector3<0.5, 0.0, 0.0>
# Band 2 range: 0.18976218464829459 at Vector3<0.5, 0.0, 0.0> to 0.2941514994479673 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.15230688173969872) to band 2 (0.18976218464829459), 21.899263388003654%
# total elapsed time for run: 3.6428568363189697
# done
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1,1.48368,0.652819)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.646884,0.267062,0.652819)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 4 and 19 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 32 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.016129032258064516, 0.0, 0.0>
#   Vector3<0.03225806451612903, 0.0, 0.0>
#   Vector3<0.04838709677419355, 0.0, 0.0>
#   Vector3<0.06451612903225806, 0.0, 0.0>
#   Vector3<0.08064516129032258, 0.0, 0.0>
#   Vector3<0.0967741935483871, 0.0, 0.0>
#   Vector3<0.11290322580645161, 0.0, 0.0>
#   Vector3<0.12903225806451613, 0.0, 0.0>
#   Vector3<0.14516129032258063, 0.0, 0.0>
#   Vector3<0.16129032258064516, 0.0, 0.0>
#   Vector3<0.1774193548387097, 0.0, 0.0>
#   Vector3<0.1935483870967742, 0.0, 0.0>
#   Vector3<0.2096774193548387, 0.0, 0.0>
#   Vector3<0.22580645161290322, 0.0, 0.0>
#   Vector3<0.24193548387096775, 0.0, 0.0>
#   Vector3<0.25806451612903225, 0.0, 0.0>
#   Vector3<0.27419354838709675, 0.0, 0.0>
#   Vector3<0.29032258064516125, 0.0, 0.0>
#   Vector3<0.3064516129032258, 0.0, 0.0>
#   Vector3<0.3225806451612903, 0.0, 0.0>
#   Vector3<0.3387096774193548, 0.0, 0.0>
#   Vector3<0.3548387096774194, 0.0, 0.0>
#   Vector3<0.3709677419354839, 0.0, 0.0>
#   Vector3<0.3870967741935484, 0.0, 0.0>
#   Vector3<0.4032258064516129, 0.0, 0.0>
#   Vector3<0.4193548387096774, 0.0, 0.0>
#   Vector3<0.43548387096774194, 0.0, 0.0>
#   Vector3<0.45161290322580644, 0.0, 0.0>
#   Vector3<0.46774193548387094, 0.0, 0.0>
#   Vector3<0.4838709677419355, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.04693269729614258
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2
# Solving for bands 2 to 2...
#     near maximum in trace
#     iteration    1: trace = 0.3142141719450085 (198.382% change)
#     iteration    2: trace = 0.1077355817086653 (97.8688% change)
#     iteration    3: trace = 0.1031483011839041 (4.35053% change)
#     iteration    4: trace = 0.09845341435772451 (4.65759% change)
#     iteration    5: trace = 0.08931839990876261 (9.72991% change)
#     iteration    6: trace = 0.08772535300645645 (1.79961% change)
#     iteration    7: trace = 0.08745323226657493 (0.310678% change)
#     iteration    8: trace = 0.08695838943593348 (0.567442% change)
#     iteration    9: trace = 0.08635247648906573 (0.699221% change)
#     iteration   10: trace = 0.08616389971460169 (0.218619% change)
#     iteration   11: trace = 0.08610864101822242 (0.0641526% change)
#     iteration   12: trace = 0.08609108250548723 (0.0203932% change)
#     iteration   13: trace = 0.08607294440861482 (0.0210707% change)
#     iteration   14: trace = 0.08606483786049383 (0.00941867% change)
#     iteration   15: trace = 0.08605725596313153 (0.00880991% change)
#     large trace change predicted (0.122795%)
#     iteration   16: trace = 0.08595132535348038 (0.123169% change)
#     iteration   17: trace = 0.08577083058450084 (0.210217% change)
#     iteration   18: trace = 0.08568721767837736 (0.0975316% change)
#     iteration   19: trace = 0.08566490980364828 (0.0260375% change)
#     iteration   20: trace = 0.08564666366667648 (0.0213017% change)
#     iteration   21: trace = 0.08561907062483286 (0.0322225% change)
#     iteration   22: trace = 0.08560442870118944 (0.0171027% change)
#     iteration   23: trace = 0.08560152408956892 (0.00339312% change)
#     iteration   24: trace = 0.08560099680222319 (0.000615981% change)
#     iteration   25: trace = 0.08560061263703525 (0.000448787% change)
#     iteration   26: trace = 0.08560015504887833 (0.000534563% change)
#     iteration   27: trace = 0.0855996975404522 (0.000534473% change)
#     iteration   28: trace = 0.08559932387395079 (0.000436529% change)
#     iteration   29: trace = 0.08559874935621384 (0.000671173% change)
#     iteration   30: trace = 0.08559803971448432 (0.000829036% change)
#     iteration   31: trace = 0.0855976071354973 (0.000505362% change)
#     iteration   32: trace = 0.08559693815711825 (0.000781542% change)
#     iteration   33: trace = 0.08559600701353876 (0.00108783% change)
#     iteration   34: trace = 0.08559542692657457 (0.000677706% change)
#     iteration   35: trace = 0.08559533252003387 (0.000110294% change)
#     iteration   36: trace = 0.08559531426559486 (2.13264e-05% change)
#     iteration   37: trace = 0.08559530533434051 (1.04343e-05% change)
#     iteration   38: trace = 0.08559529026174659 (1.76091e-05% change)
#     iteration   39: trace = 0.08559528371155771 (7.65251e-06% change)
# Finished solving for bands 2 to 2 after 39 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.292567
# elapsed time for k point: 0.1205742359161377
# solve_kpoint (0.016129,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.08538073498297112 (0.357865% change)
#     iteration    2: trace = 0.0852308623675801 (0.175689% change)
#     iteration    3: trace = 0.08518935576389339 (0.0487109% change)
#     iteration    4: trace = 0.08516508159759471 (0.0284984% change)
#     iteration    5: trace = 0.0851493680172386 (0.0184524% change)
#     iteration    6: trace = 0.08513871043925293 (0.0125171% change)
#     iteration    7: trace = 0.0851312841291476 (0.00872298% change)
#     iteration    8: trace = 0.08512600611516544 (0.00620004% change)
#     iteration    9: trace = 0.08512218536129859 (0.00448845% change)
#     iteration   10: trace = 0.08511936296404858 (0.00331576% change)
#     iteration   11: trace = 0.08511722717916395 (0.0025092% change)
#     iteration   12: trace = 0.08511556301601132 (0.00195516% change)
#     iteration   13: trace = 0.08511422015279978 (0.00157771% change)
#     iteration   14: trace = 0.08511309164084532 (0.00132589% change)
#     iteration   15: trace = 0.08511209942064517 (0.00116577% change)
#     iteration   16: trace = 0.08511118433094632 (0.00107516% change)
#     iteration   17: trace = 0.08511029918612818 (0.00103999% change)
#     iteration   18: trace = 0.08510940404589723 (0.00105175% change)
#     iteration   19: trace = 0.08510846316902766 (0.0011055% change)
#     iteration   20: trace = 0.08510744339146914 (0.00119822% change)
#     iteration   21: trace = 0.08510631380861097 (0.00132725% change)
#     iteration   22: trace = 0.08510504665415897 (0.00148892% change)
#     iteration   23: trace = 0.08510361913765174 (0.00167737% change)
#     iteration   24: trace = 0.08510201575742606 (0.00188405% change)
#     iteration   25: trace = 0.08510023035671867 (0.00209798% change)
#     iteration   26: trace = 0.08509826711576865 (0.002307% change)
#     iteration   27: trace = 0.08509613991604321 (0.00249973% change)
#     iteration   28: trace = 0.08509387004716228 (0.00266745% change)
#     iteration   29: trace = 0.08509148281887249 (0.00280545% change)
#     iteration   30: trace = 0.08508900399100124 (0.00291318% change)
#     iteration   31: trace = 0.08508645689431979 (0.00299349% change)
#     iteration   32: trace = 0.08508386077179937 (0.0030512% change)
#     iteration   33: trace = 0.08508123044344058 (0.0030915% change)
#     iteration   34: trace = 0.08507857707480238 (0.00311868% change)
#     iteration   35: trace = 0.08507590967365093 (0.00313527% change)
#     iteration   36: trace = 0.08507323691451152 (0.00314167% change)
#     iteration   37: trace = 0.08507056892816679 (0.00313615% change)
#     iteration   38: trace = 0.08506791874275804 (0.00311533% change)
#     iteration   39: trace = 0.08506530311303589 (0.0030748% change)
#     iteration   40: trace = 0.08506274254151318 (0.00301017% change)
#     iteration   41: trace = 0.08506026040464221 (0.00291805% change)
#     iteration   42: trace = 0.08505788125723096 (0.00279705% change)
#     iteration   43: trace = 0.08505562857468968 (0.00264845% change)
#     iteration   44: trace = 0.08505352234877718 (0.00247632% change)
#     iteration   45: trace = 0.08505157701276732 (0.00228722% change)
#     iteration   46: trace = 0.08504980009831217 (0.00208924% change)
#     iteration   47: trace = 0.0850481918353769 (0.00189098% change)
#     iteration   48: trace = 0.08504674566696183 (0.00170042% change)
#     iteration   49: trace = 0.08504544944817284 (0.00152414% change)
#     iteration   50: trace = 0.08504428699539963 (0.00136687% change)
#     iteration   51: trace = 0.08504323965744603 (0.00123153% change)
#     iteration   52: trace = 0.08504228766503172 (0.00111943% change)
#     iteration   53: trace = 0.08504141112980959 (0.00103071% change)
#     iteration   54: trace = 0.0850405906686918 (0.000964783% change)
#     iteration   55: trace = 0.08503980770361863 (0.0009207% change)
#     iteration   56: trace = 0.0850390445292354 (0.000897436% change)
#     iteration   57: trace = 0.08503828425987683 (0.000894028% change)
#     iteration   58: trace = 0.08503751077345738 (0.000909578% change)
#     iteration   59: trace = 0.08503670877024254 (0.000943121% change)
#     iteration   60: trace = 0.08503586405904932 (0.000993354% change)
#     iteration   61: trace = 0.08503496416411535 (0.00105826% change)
#     iteration   62: trace = 0.08503399929768402 (0.00113468% change)
#     iteration   63: trace = 0.08503296365022138 (0.00121793% change)
#     iteration   64: trace = 0.08503185680814596 (0.00130167% change)
#     iteration   65: trace = 0.08503068494516687 (0.00137816% change)
#     iteration   66: trace = 0.08502946131892013 (0.00143905% change)
#     iteration   67: trace = 0.0850282056388654 (0.00147677% change)
#     iteration   68: trace = 0.08502694212184832 (0.00148601% change)
#     iteration   69: trace = 0.08502569647493986 (0.00146501% change)
#     resetting CG direction...
#     large trace change predicted (0.076557%)
#     iteration   70: trace = 0.08496050398307695 (0.0767033% change)
#     iteration   71: trace = 0.08490447983827448 (0.0659631% change)
#     iteration   72: trace = 0.08487218722661287 (0.0380413% change)
#     iteration   73: trace = 0.0848687395170029 (0.00406232% change)
#     iteration   74: trace = 0.08486776876414084 (0.00114384% change)
#     iteration   75: trace = 0.0848676442438193 (0.000146723% change)
#     iteration   76: trace = 0.08486763965295242 (5.40944e-06% change)
# Finished solving for bands 1 to 2 after 76 iterations.
# tmfreqs:, 2, 0.016129, 0, 0, 0.016129, 0.00497571, 0.291278
# elapsed time for k point: 1.0976436138153076
# solve_kpoint (0.0322581,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.08346219669980173 (0.204972% change)
#     iteration    2: trace = 0.08322716690452855 (0.281997% change)
#     iteration    3: trace = 0.08321898693885146 (0.00982896% change)
#     iteration    4: trace = 0.083218028915011 (0.00115121% change)
#     iteration    5: trace = 0.0832177669533334 (0.00031479% change)
#     iteration    6: trace = 0.08321747990337688 (0.000344939% change)
#     iteration    7: trace = 0.08321742013160226 (7.1826e-05% change)
#     iteration    8: trace = 0.08321740337487132 (2.01361e-05% change)
#     iteration    9: trace = 0.08321739661478809 (8.1234e-06% change)
# Finished solving for bands 1 to 2 after 9 iterations.
# tmfreqs:, 3, 0.0322581, 0, 0, 0.0322581, 0.00995118, 0.288303
# elapsed time for k point: 0.16803741455078125
# solve_kpoint (0.0483871,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.08132900912791786 (0.124296% change)
#     iteration    2: trace = 0.08123176625638427 (0.119639% change)
#     iteration    3: trace = 0.08122720723544737 (0.00561252% change)
#     iteration    4: trace = 0.08122685052679977 (0.00043915% change)
#     iteration    5: trace = 0.08122677126282019 (9.75835e-05% change)
#     iteration    6: trace = 0.08122676480671853 (7.94824e-06% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 4, 0.0483871, 0, 0, 0.0483871, 0.0149261, 0.284612
# elapsed time for k point: 0.11158919334411621
# solve_kpoint (0.0645161,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.0791728195989264 (0.0978859% change)
#     iteration    2: trace = 0.0791262159633986 (0.0588805% change)
#     iteration    3: trace = 0.07912383443655187 (0.00300983% change)
#     iteration    4: trace = 0.07912365795879955 (0.00022304% change)
#     iteration    5: trace = 0.07912362456280389 (4.22074e-05% change)
#     iteration    6: trace = 0.07912362195977132 (3.28983e-06% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 5, 0.0645161, 0, 0, 0.0645161, 0.0199003, 0.280584
# elapsed time for k point: 0.12732219696044922
# solve_kpoint (0.0806452,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.07702380862396228 (0.0869427% change)
#     iteration    2: trace = 0.07699787531422998 (0.0336749% change)
#     iteration    3: trace = 0.0769965374015501 (0.00173761% change)
#     iteration    4: trace = 0.07699645832205279 (0.000102705% change)
#     iteration    5: trace = 0.07699644712221283 (1.45459e-05% change)
#     iteration    6: trace = 0.07699644619357145 (1.20608e-06% change)
# Finished solving for bands 1 to 2 after 6 iterations.
# tmfreqs:, 6, 0.0806452, 0, 0, 0.0806452, 0.0248735, 0.276365
# elapsed time for k point: 0.15986037254333496
# solve_kpoint (0.0967742,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.07490361937383846 (0.0817994% change)
#     iteration    2: trace = 0.07488767681384322 (0.0212864% change)
#     iteration    3: trace = 0.0748868572285049 (0.00109443% change)
#     iteration    4: trace = 0.07488681730744766 (5.33085e-05% change)
#     iteration    5: trace = 0.07488681355062922 (5.01666e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 7, 0.0967742, 0, 0, 0.0967742, 0.0298454, 0.272022
# elapsed time for k point: 0.13082218170166016
# solve_kpoint (0.112903,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.07282861593216504 (0.0792311% change)
#     iteration    2: trace = 0.0728181421753645 (0.0143824% change)
#     iteration    3: trace = 0.07281761135702124 (0.000728967% change)
#     iteration    4: trace = 0.07281758892485589 (3.0806e-05% change)
#     iteration    5: trace = 0.07281758761102847 (1.80427e-06% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 8, 0.112903, 0, 0, 0.112903, 0.0348157, 0.267592
# elapsed time for k point: 0.0973665714263916
# solve_kpoint (0.129032,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.07081034090492146 (0.0782328% change)
#     iteration    2: trace = 0.07080314835875434 (0.010158% change)
#     iteration    3: trace = 0.07080279296343042 (0.00050195% change)
#     iteration    4: trace = 0.07080277920061542 (1.94382e-05% change)
#     iteration    5: trace = 0.07080277867718873 (7.39274e-07% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 9, 0.129032, 0, 0, 0.129032, 0.0397842, 0.263097
# elapsed time for k point: 0.1042182445526123
# solve_kpoint (0.145161,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06885698319620658 (0.0780672% change)
#     iteration    2: trace = 0.06885187974079329 (0.00741195% change)
#     iteration    3: trace = 0.06885163632915367 (0.00035353% change)
#     iteration    4: trace = 0.06885162743114408 (1.29235e-05% change)
#     iteration    5: trace = 0.06885162718989132 (3.50395e-07% change)
# Finished solving for bands 1 to 2 after 5 iterations.
# tmfreqs:, 10, 0.145161, 0, 0, 0.145161, 0.0447507, 0.258552
# elapsed time for k point: 0.08468770980834961
# solve_kpoint (0.16129,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06697444294020294 (0.0784527% change)
#     iteration    2: trace = 0.06697072898489718 (0.00554549% change)
#     iteration    3: trace = 0.06697055979596706 (0.000252631% change)
#     iteration    4: trace = 0.06697055384488759 (8.88611e-06% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 11, 0.16129, 0, 0, 0.16129, 0.0497147, 0.253967
# elapsed time for k point: 0.10610437393188477
# solve_kpoint (0.177419,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06516707709589908 (0.0792438% change)
#     iteration    2: trace = 0.06516431756211277 (0.00423464% change)
#     iteration    3: trace = 0.06516419858317814 (0.000182583% change)
#     iteration    4: trace = 0.06516419453175946 (6.21725e-06% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 12, 0.177419, 0, 0, 0.177419, 0.0546761, 0.249349
# elapsed time for k point: 0.10241031646728516
# solve_kpoint (0.193548,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06343817171722335 (0.0802867% change)
#     iteration    2: trace = 0.06343608484611661 (0.00328967% change)
#     iteration    3: trace = 0.06343600080839988 (0.000132476% change)
#     iteration    4: trace = 0.06343599800198266 (4.42401e-06% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 13, 0.193548, 0, 0, 0.193548, 0.0596345, 0.244703
# elapsed time for k point: 0.03956460952758789
# solve_kpoint (0.209677,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06179025597675884 (0.0815382% change)
#     iteration    2: trace = 0.06178865249202151 (0.00259508% change)
#     iteration    3: trace = 0.06178859282202748 (9.65712e-05% change)
#     iteration    4: trace = 0.06178859086462645 (3.1679e-06% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 14, 0.209677, 0, 0, 0.209677, 0.0645895, 0.240035
# elapsed time for k point: 0.04758262634277344
# solve_kpoint (0.225806,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.06022530721289832 (0.0829412% change)
#     iteration    2: trace = 0.06022405688357756 (0.00207611% change)
#     iteration    3: trace = 0.06022401430223306 (7.07049e-05% change)
#     iteration    4: trace = 0.06022401293212329 (2.27502e-06% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 15, 0.225806, 0, 0, 0.225806, 0.0695409, 0.235347
# elapsed time for k point: 0.04194998741149902
# solve_kpoint (0.241935,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.05874489444643041 (0.084452% change)
#     iteration    2: trace = 0.05874390571946179 (0.0016831% change)
#     iteration    3: trace = 0.05874387513430147 (5.20653e-05% change)
#     iteration    4: trace = 0.05874387417276471 (1.63683e-06% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 16, 0.241935, 0, 0, 0.241935, 0.0744883, 0.230641
# elapsed time for k point: 0.05501556396484375
# solve_kpoint (0.258065,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.05735027825380817 (0.0860349% change)
#     iteration    2: trace = 0.0573494856075718 (0.00138212% change)
#     iteration    3: trace = 0.05734946342013517 (3.86881e-05% change)
#     iteration    4: trace = 0.05734946274192119 (1.1826e-06% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 17, 0.258065, 0, 0, 0.258065, 0.0794311, 0.225921
# elapsed time for k point: 0.06031489372253418
# solve_kpoint (0.274194,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.0560424822488713 (0.0876595% change)
#     iteration    2: trace = 0.05604183807126716 (0.00114945% change)
#     iteration    3: trace = 0.05604182172486085 (2.91682e-05% change)
#     iteration    4: trace = 0.05604182124044522 (8.64382e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 18, 0.274194, 0, 0, 0.274194, 0.0843689, 0.221187
# elapsed time for k point: 0.05391502380371094
# solve_kpoint (0.290323,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.0548223451499521 (0.0892988% change)
#     iteration    2: trace = 0.05482181438002887 (0.000968168% change)
#     iteration    3: trace = 0.05482180205539421 (2.24813e-05% change)
#     switching to approximate line minimization (decrease time by 91.65%)
#     iteration    4: trace = 0.0548218017001298 (6.48035e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 19, 0.290323, 0, 0, 0.290323, 0.0893011, 0.216442
# elapsed time for k point: 0.05279803276062012
# solve_kpoint (0.306452,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.05369055930938176 (0.0909278% change)
#     switching to approximate line minimization (decrease time by 95.7204%)
#     iteration    2: trace = 0.05369011582124553 (0.000826011% change)
#     iteration    3: trace = 0.05369010622652523 (1.78706e-05% change)
#     switching back to exact line minimization
#     iteration    4: trace = 0.05369010595404499 (5.07505e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 20, 0.306452, 0, 0, 0.306452, 0.0942269, 0.211687
# elapsed time for k point: 0.09682321548461914
# solve_kpoint (0.322581,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.05264769962386265 (0.0925236% change)
#     iteration    2: trace = 0.05264732373866254 (0.000713966% change)
#     iteration    3: trace = 0.05264731596144792 (1.47723e-05% change)
#     iteration    4: trace = 0.05264731573966749 (4.21257e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 21, 0.322581, 0, 0, 0.322581, 0.0991456, 0.206924
# elapsed time for k point: 0.07385993003845215
# solve_kpoint (0.33871,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.05169424549272925 (0.0940645% change)
#     iteration    2: trace = 0.05169392223625141 (0.000625326% change)
#     iteration    3: trace = 0.05169391563778011 (1.27645e-05% change)
#     iteration    4: trace = 0.05169391544622733 (3.70552e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 22, 0.33871, 0, 0, 0.33871, 0.104056, 0.202154
# elapsed time for k point: 0.071929931640625
# solve_kpoint (0.354839,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.05083059766682007 (0.0955297% change)
#     iteration    2: trace = 0.05083031553177902 (0.000555051% change)
#     iteration    3: trace = 0.05083030967063012 (1.15308e-05% change)
#     iteration    4: trace = 0.05083030949804593 (3.3953e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 23, 0.354839, 0, 0, 0.354839, 0.108956, 0.19738
# elapsed time for k point: 0.04538273811340332
# solve_kpoint (0.370968,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.05005709129114084 (0.0968998% change)
#     iteration    2: trace = 0.05005684134350659 (0.000499326% change)
#     iteration    3: trace = 0.05005683592033115 (1.0834e-05% change)
#     iteration    4: trace = 0.05005683576195519 (3.16392e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 24, 0.370968, 0, 0, 0.370968, 0.113844, 0.192604
# elapsed time for k point: 0.03907442092895508
# solve_kpoint (0.387097,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.04937400606158823 (0.0981565% change)
#     iteration    2: trace = 0.04937378128974 (0.000455244% change)
#     iteration    3: trace = 0.04937377610718355 (1.04966e-05% change)
#     iteration    4: trace = 0.04937377596189248 (2.94268e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 25, 0.387097, 0, 0, 0.387097, 0.118716, 0.187831
# elapsed time for k point: 0.0295407772064209
# solve_kpoint (0.403226,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.04878157417001062 (0.0992828% change)
#     iteration    2: trace = 0.04878136900512846 (0.00042058% change)
#     iteration    3: trace = 0.04878136393850543 (1.03864e-05% change)
#     iteration    4: trace = 0.04878136380642572 (2.70759e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 26, 0.403226, 0, 0, 0.403226, 0.123567, 0.183065
# elapsed time for k point: 0.0659933090209961
# solve_kpoint (0.419355,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.048279986526855 (0.100263% change)
#     iteration    2: trace = 0.04827979648479545 (0.000393626% change)
#     iteration    3: trace = 0.04827979146026093 (1.04071e-05% change)
#     iteration    4: trace = 0.04827979134128428 (2.46432e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 27, 0.419355, 0, 0, 0.419355, 0.128386, 0.178317
# elapsed time for k point: 0.0885477066040039
# solve_kpoint (0.435484,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.04786939762061382 (0.101084% change)
#     iteration    2: trace = 0.04786921903005136 (0.000373079% change)
#     iteration    3: trace = 0.04786921400819691 (1.04908e-05% change)
#     iteration    4: trace = 0.04786921390136734 (2.2317e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 28, 0.435484, 0, 0, 0.435484, 0.133156, 0.173605
# elapsed time for k point: 0.12986207008361816
# solve_kpoint (0.451613,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.04754992927797846 (0.101734% change)
#     iteration    2: trace = 0.04754975907007142 (0.000357957% change)
#     iteration    3: trace = 0.04754975403375319 (1.05917e-05% change)
#     iteration    4: trace = 0.04754975393722319 (2.03008e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 29, 0.451613, 0, 0, 0.451613, 0.137835, 0.168972
# elapsed time for k point: 0.0612642765045166
# solve_kpoint (0.467742,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.04732167351889361 (0.102204% change)
#     iteration    2: trace = 0.04732150906076026 (0.000347533% change)
#     iteration    3: trace = 0.04732150400636925 (1.0681e-05% change)
#     iteration    4: trace = 0.04732150391761029 (1.87566e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 30, 0.467742, 0, 0, 0.467742, 0.142315, 0.164524
# elapsed time for k point: 0.07397174835205078
# solve_kpoint (0.483871,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.04718469464787378 (0.102486% change)
#     iteration    2: trace = 0.04718453360680271 (0.0003413% change)
#     iteration    3: trace = 0.04718452853828005 (1.07419e-05% change)
#     iteration    4: trace = 0.04718452845434652 (1.77884e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 31, 0.483871, 0, 0, 0.483871, 0.146228, 0.16063
# elapsed time for k point: 0.05774092674255371
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 2...
#     iteration    1: trace = 0.04713903068155217 (0.102577% change)
#     iteration    2: trace = 0.04713887090994979 (0.000338938% change)
#     iteration    3: trace = 0.04713886583484088 (1.07663e-05% change)
#     iteration    4: trace = 0.047138865752593 (1.7448e-07% change)
# Finished solving for bands 1 to 2 after 4 iterations.
# tmfreqs:, 32, 0.5, 0, 0, 0.5, 0.148137, 0.158727
# elapsed time for k point: 0.05209517478942871
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.14813693412661275 at Vector3<0.5, 0.0, 0.0>
# Band 2 range: 0.158727170012448 at Vector3<0.5, 0.0, 0.0> to 0.2925667166845157 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.14813693412661275) to band 2 (0.158727170012448), 6.9022317977185725%
# total elapsed time for run: 3.6978936195373535
# done
# The mid-point for the TE mode is at 152.25626100355782 (dashed black line)
# The largest bandgap is 33.34299962189542 THz thick for TE modes
# The mid-point for the TM mode is at 136.5863965010656 (dashed black line)
# The largest bandgap is 9.427509690654517 THz thick for TM modes
# [16.671499810947722, 152.25626100355782, 4.713754845327259, 136.5863965010656]
