# %%
import utils as u
import matplotlib.pyplot as plt
import numpy as np
import meep as mp
# %matplotlib inline

# %%
taper = u.tapering(380, 180, 10)
print(mp.Ex, mp.Ey, mp.Ez, mp.Hx, mp.Hy, mp.Hz)
Qs, freqs = u.defectandmirrors(500, length = 337, xlength= 218, ylengths = taper, mirrorlength=382, excitation = mp.Hz)
# Out:
# ...
# 0 1 4 5 6 9
# 9
# magentic
#      block, center = (0,0,0)
#           size (35,1.48368,0.652819)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      ellipsoid, center = (-9,0,0)
#           size (0.646884,1.12166,0.652819)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ellipsoid, center = (9,0,0)
#           size (0.646884,1.12166,0.652819)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ellipsoid, center = (-8,0,0)
#           size (0.646884,1.10386,0.652819)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ellipsoid, center = (8,0,0)
#           size (0.646884,1.10386,0.652819)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ellipsoid, center = (-7,0,0)
# ...
